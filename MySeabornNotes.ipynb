# %% [markdown]
# # MY SEABORN NOTES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamonds=sns.load_dataset("diamonds")
flights=sns.load_dataset("flights")
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(tips.size)
# Out:
# numpy.int32

# %%
tips["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(data=tips, x= "total_bill", y= "tip")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=tips.total_bill, y=tips.tip)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data= tips, x="total_bill", y= "tip", hue="smoker")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data= tips, x="total_bill", y= "tip", hue="sex")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data= tips, x="total_bill", y= "tip", hue="day")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=tips, x="total_bill", y="tip", style="sex", hue="sex")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data= tips, x="total_bill", y= "tip", style="day", hue="day")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data= tips, x="total_bill", y= "tip", style="day", hue="sex")
plt.show()

# %%
fig, hg = plt.subplots(1, 2, figsize= (10,5))
sns.scatterplot(data=tips, x= "total_bill", y= "tip", style= "sex", ax= hg[0]);
sns.scatterplot(data=tips, x= "total_bill", y= "tip", hue= "smoker", ax= hg[1]);
plt.show()

# %%
plt.figure(figsize= (10,6))
sns.scatterplot(data= tips, x= "total_bill", y= "tip", hue= "sex", palette = "plasma", alpha= 0.3);

# %%
plt.figure(figsize= (10,6))
sns.scatterplot(data= tips, x= "total_bill", y="tip", style="sex", hue="day", alpha= 0.7, s=200)
plt.show()

# %%
# HISTPLOT

x = np.random.rand(2000)
plt.hist(x, bins = 30, color ="#D3AC0D")
plt.gca().set(title = "Histogram", ylabel = "Frequency")
plt.show()

# %%
sns.displot(x="total_bill", data=tips);
sns.displot(tips["total_bill"])
plt.show()

# %%
sns.displot(tips["total_bill"])
plt.show()

# %%
sns.displot(tips.total_bill)
plt.show()

# %%
sns.displot(tips.total_bill, kde=True, bins= 50)
plt.show()

# %%
sns.displot(tips.tip, kde=True, bins=50)
plt.show()

# %%
fig, ax = plt.subplots (1,2, figsize=(10,5))
sns.scatterplot(data=tips, x="total_bill", y="tip", s=300, hue="sex", ax=ax[0])
sns.displot(data= tips, x="total_bill", ax=ax[1])
plt.show()

# %%
fig, ax = plt.subplots (1,2, figsize=(10,5))
sns.scatterplot(data=tips, x="total_bill", y="tip", s=300, hue="sex", ax=ax[0])
sns.histplot(data= tips, x="total_bill", ax=ax[1])
plt.show()

# %%
sns.displot(data=tips, x= "total_bill", kind="hist")
sns.displot(data=tips, x= "total_bill", kind="kde")
plt.show()

# %%
sns.displot(tips.total_bill, kind="hist", kde=True)
plt.show()

# %%
sns.displot(tips.total_bill, kind= "hist", kde= True, aspect=2)

# %%
plt.figure(figsize=(6,4))
sns.histplot(data=tips, x="tip", bins=50)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=tips, x="tip")
plt.show()

# %%
fig, ax=plt.subplots(1,2, figsize=(10,5))
sns.rugplot(tips.total_bill, height= 0.8, ax=ax[0])
sns.histplot(tips.tip, kde= True, ax=ax[1])
plt.show()

# %%
sns.set(style="dark")
sns.histplot(tips.tip, kde=True)
plt.show()

# %%
penguins= sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.kdeplot(data=penguins, x= "body_mass_g")
plt.show()

# %%
sns.kdeplot(data=penguins, x="body_mass_g",  hue="sex");
plt.show()

# %%
penguins.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
sns.kdeplot(data= penguins, x="body_mass_g", hue="species", shade=True)
plt.show()

# %%
sns.kdeplot(data=penguins, x="bill_length_mm", hue="sex", shade=True)
plt.show()

# %%
sns.kdeplot(data= tips, x="total_bill", y="tip")
plt.show()

# %%
sns.scatterplot(data= tips, x="total_bill", y="tip")
plt.show()

# %%
sns.kdeplot(data= tips, x="total_bill", y="tip", color="red")
plt.show()

# %%
sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red", shade=True);

# %%
fig, ax= plt.subplots(1,2, figsize=(10,6))
sns.kdeplot(data=tips, x="total_bill", y="tip", shade= True, color="red", ax=ax[0]);
sns.scatterplot(data=tips, x="total_bill", y= "tip", color="red", ax=ax[1]);
plt.show()

# %%
fig, ax= plt.subplots(1,2, figsize=(10,6))
sns.kdeplot(data=tips, x="total_bill", y="tip", shade= True, color="red", ax=ax[1]);
sns.scatterplot(data=tips, x="total_bill", y= "tip", color="green", ax=ax[0]);
plt.show()

# %%
sns.histplot(data=penguins, x="body_mass_g", kde=True, bins=10)
plt.show()

# %%
sns.jointplot(data= tips, x="total_bill", y= "tip", kind= "scatter")
plt.show()

# %%
sns.jointplot(data= tips, x="total_bill", y= "tip", kind="hex")
plt.show()

# %%
sns.jointplot(data= tips, x="total_bill", y= "tip", kind="hist")
plt.show()

# %%
sns.jointplot(data= tips, x="total_bill", y= "tip", kind="kde", shade="True")
plt.show()

# %%
plt.figure(figsize=(10,5))
markers={"Male":">", "Female":"<"}
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="sex", s=200, markers=markers);
plt.show()

# %%
plt.figure(figsize = (10, 5))
markers = {"Male": ">", "Female": "<"}
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = "sex", style = "sex", s = 150, markers = markers);

# %%
sns.pairplot(data=tips)
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
mpg=sns.load_dataset("mpg")
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.countplot(x="day", data= tips)
plt.show()

# %%
sns.countplot(x="day", data=tips, hue="smoker")
plt.show()

# %%
sns.countplot(x="day", data=tips, hue="sex")
plt.show()

# %%
sns.countplot(x="day", data=tips, hue="size")
plt.show()

# %%
plt.subplots()

# %%
    x = np.linspace(0, 2*np.pi, 400)
    y = np.sin(x**2)

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')
# Out:
# Text(0.5, 1.0, 'Simple plot')

# %%
    f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
    ax1.plot(x, y)
    ax1.set_title('Sharing Y axis')
    ax2.scatter(x, y)

# %%
    fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
    axs[0, 0].plot(x, y)

# %%
    plt.subplots(2, 2, sharex='col')
# Out:
# (<Figure size 432x288 with 4 Axes>,
#  array([[<AxesSubplot:>, <AxesSubplot:>],
#         [<AxesSubplot:>, <AxesSubplot:>]], dtype=object))

# %%
fig, ax= plt.subplots()
ax=sns.countplot(x="day", data=tips)

for p in ax.patches:

# %%
fig, ax_tip = plt.subplots()
ax_tip = sns.countplot(x = "day", data = tips);

for p in ax_tip.patches:
    ax_tip.annotate("%"+str(round(p.get_height() / tips.day.count()*100, 1)), (p.get_x()+0.3, p.get_height()));
    ax_tip.annotate(p.get_height(), (p.get_x()+0.3, p.get_height()-5))

# %%
sns.barplot("sex", "tip", data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot("sex", "tip", data=tips, estimator=np.sum);

# %%
sns.barplot("sex", "tip", data=tips, estimator=np.min);

# %%
sns.barplot("sex", "tip", data=tips, estimator=np.mean, ci="sd");

# %%
sns.barplot("sex", "tip", data=tips, estimator=np.mean, ci="sd", hue="smoker");

# %%
fig, ax_tip= plt.subplots()
ax_tip= sns.countplot(x="day", data=tips);

for p in ax_tip.patches:
    ax_tip.annotate("("+
                   str(p.get_height()) +
                   ")" +
                   "%" +
                   str(round((p.get_height()) / tips.day.count(), 2)*100), (p.get_x()+0.07, p.get_height()-10));

# %%
fig, ax= plt.subplots(nrows=1, ncols=2, figsize=[16,6])

sns.barplot(data=tips, x="day", y="total_bill", ax=ax[0])
sns.countplot(data=tips, x="day", ax=ax[1]);

# %%
fig,ax= plt.subplots(nrows=1, ncols=2, figsize=(16,6))

sns.barplot(data=tips, x="day", y="total_bill", ax=ax[0], estimator=np.median)
sns.countplot(data=tips, x="day", ax=ax[1]);

# %%
sns.boxplot(data=tips, x="day", y="tip");

# %%
sns.boxplot(data=tips, x="day", y="total_bill");

# %%
sns.boxplot(data=tips, x="day", y="total_bill", hue="sex");

# %%
sns.boxplot(data=tips, x="day", y="total_bill", hue="smoker");

# %%
sns.boxplot(data=tips, y="day", x="tip", hue="sex");

# %%
sns.boxplot(data=tips, y="day", x="tip", hue="sex", width=0.5);

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=tips, y="day", x="tip", hue="sex", width=0.3);
plt.legend(loc=6);

# %% [markdown]
# # VIOLIN PLOT

# %%
plt.figure(figsize=(10,6))

sns.violinplot(x="day", y="tip", data=tips);

# %%
plt.figure(figsize=(10,6))

sns.violinplot(data=tips, x="day", y="tip", hue="sex");

# %%
plt.figure(figsize=(10,6))

sns.violinplot(data=tips, x="tip", y="day", hue="sex");

# %%
plt.figure(figsize=(10,6))

sns.violinplot(data=tips, x="tip", y="day", hue="sex", split=True, bw=0.3);

# %% [markdown]
# # Swarm Plot

# %%
plt.figure(figsize=(10,6))

sns.swarmplot(data=tips, x="total_bill", y="smoker", size=10);

# %%
plt.figure(figsize=(12,6))

sns.swarmplot(data=tips, x="total_bill", y="smoker", size=10, hue="sex");

# %%
plt.figure(figsize=(12,6))

sns.swarmplot(data=tips, x="smoker", y="total_bill", hue="sex", size=10);

# %%
plt.figure(figsize=(12,6))

sns.swarmplot(data=tips, x="total_bill", y="smoker", hue="sex", size=10, dodge=True);

# %% [markdown]
# # Boxen Plot

# %%
sns.boxenplot(data=tips, x="day", y="tip");

# %%
sns.boxplot(data=tips, x="day", y="tip");

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot("year", "passengers", data=flights);

# %%
flights.groupby(["year", "month"]).sum()
# Out:
#             passengers
# year month
# 1949 Jan           112
#      Feb           118
#      Mar           132
#      Apr           129
#      May           121
# ...                ...
# 1960 Aug           606
#      Sep           508
#      Oct           461
#      Nov           390
#      Dec           432
#
# [144 rows x 1 columns]

# %%
flights.groupby(["year", "month"]).sum().values
# Out:
# array([[112],
#        [118],
#        [132],
#        [129],
#        [121],
#        [135],
#        [148],
#        [148],
#        [136],
#        [119],
#        [104],
#        [118],
#        [115],
#        [126],
#        [141],
#        [135],
#        [125],
#        [149],
#        [170],
#        [170],
#        [158],
#        [133],
#        [114],
#        [140],
#        [145],
#        [150],
#        [178],
#        [163],
#        [172],
#        [178],
#        [199],
#        [199],
#        [184],
#        [162],
#        [146],
#        [166],
#        [171],
#        [180],
#        [193],
#        [181],
#        [183],
#        [218],
#        [230],
#        [242],
#        [209],
#        [191],
#        [172],
#        [194],
#        [196],
#        [196],
#        [236],
#        [235],
#        [229],
#        [243],
#        [264],
#        [272],
#        [237],
#        [211],
#        [180],
#        [201],
#        [204],
#        [188],
# ...

# %%
flights.index
# Out:
# RangeIndex(start=0, stop=144, step=1)

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x=flights.index, y= flights.passengers.values)
plt.show()

# %%
flights_wide= flights.pivot("year", "month", "passengers")
flights_wide.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=flights_wide.T);
